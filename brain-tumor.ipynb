# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_124.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_949.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_786.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_371.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_599.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_802.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1323.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1347.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_955.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_778.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1354.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_470.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_872.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_904.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_66.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_787.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1274.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_877.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_333.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1271.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_182.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1283.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_578.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_576.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1204.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1084.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1358.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_110.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_499.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1200.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1057.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_665.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_91.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_695.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_118.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_625.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1139.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_322.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_450.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1310.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_319.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1384.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_528.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_121.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1299.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1202.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1276.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_810.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_758.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_436.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_262.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1039.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_31.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1390.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_316.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_970.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_126.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_453.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_813.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_622.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1100.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1225.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_206.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_483.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_770.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_819.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_725.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1137.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1217.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1069.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_735.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_980.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1009.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_148.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_795.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_501.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_27.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1109.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1170.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_47.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_957.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_895.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_373.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1053.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1336.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_84.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_254.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_183.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1286.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_615.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_935.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_11.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1349.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_70.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1178.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_679.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1221.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1394.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_946.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_551.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_425.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1277.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_847.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_152.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1001.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_558.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_874.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1201.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_881.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_241.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1161.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_95.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_343.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1226.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1004.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1020.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1337.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_764.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1326.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_783.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_291.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1062.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1379.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_60.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1101.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_122.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_502.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_264.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_479.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1172.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_486.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_848.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_329.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_703.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_631.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1028.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1252.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_914.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_367.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1105.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_466.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1245.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_270.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_887.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1179.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_235.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_640.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_637.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_821.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1247.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1163.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_119.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_815.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_35.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_889.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_79.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_12.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_314.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_684.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_547.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_409.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1191.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_968.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1222.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1043.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_585.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_114.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1038.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_867.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_988.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_402.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_715.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1220.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_274.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_171.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1285.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1287.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_93.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1127.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_526.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_338.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_945.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_680.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1360.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_388.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1270.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_97.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1213.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_128.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_107.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_26.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1269.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_245.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_993.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_617.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_304.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1288.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_458.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_125.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_755.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1284.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_460.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_145.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_739.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1364.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_947.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_135.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_306.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_167.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1361.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_777.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_731.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_825.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_788.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_602.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_672.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_403.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_923.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_546.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_209.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1317.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_165.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1316.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1244.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_799.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1399.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_252.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_699.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_74.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1230.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1325.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1079.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_32.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_944.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_525.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1229.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_216.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_890.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_293.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_817.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_809.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_295.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_227.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_303.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1356.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_268.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_380.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_281.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_843.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_666.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_590.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_210.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_834.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_393.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_681.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_159.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_865.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_917.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1307.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_112.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_592.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_422.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_692.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_370.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1186.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_994.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_941.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_378.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_213.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_726.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_586.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1176.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_844.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1400.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1124.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_240.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_928.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_689.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_86.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1032.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_900.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_567.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_981.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_258.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_233.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_111.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1146.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_426.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_376.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_468.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_687.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_44.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_399.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_663.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1203.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1149.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1060.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1033.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_357.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_604.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_134.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_870.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_883.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_321.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_650.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_584.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_487.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1313.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_494.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_469.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_857.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1022.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_987.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_430.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_397.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1155.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_447.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1115.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_522.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_221.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1279.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_916.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_912.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_481.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1073.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_161.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1010.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1381.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_589.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1293.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1378.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_405.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1158.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_340.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_971.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_711.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_101.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1021.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1117.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_197.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1153.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1370.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_509.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1087.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_892.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_173.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_263.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1236.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_962.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1320.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_796.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1300.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_311.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_598.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1301.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1145.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_780.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_457.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1372.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_669.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_922.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_775.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_461.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1206.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_190.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_89.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1045.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1030.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1280.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_416.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_632.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_837.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_550.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1282.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1249.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_668.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1046.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_869.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1196.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1112.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_309.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1218.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_102.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1207.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1241.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1102.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_753.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_19.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_523.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_937.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1078.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_490.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_320.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_382.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_939.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_168.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1013.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_664.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_768.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_88.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1147.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_435.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_78.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_296.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_301.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1093.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1003.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1136.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_360.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1396.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_475.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_482.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1061.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_200.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_565.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_222.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_643.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_940.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_218.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_508.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_580.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_879.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_157.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_24.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_406.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1198.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_15.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_452.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_920.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_667.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_605.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_155.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_511.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_236.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_288.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_998.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_137.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1190.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_283.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1208.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_859.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1365.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_875.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_524.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1052.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1048.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1233.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_894.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_728.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_217.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_671.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_323.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_818.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1371.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_52.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_73.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_202.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_377.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_149.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1232.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_318.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1289.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_646.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_215.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_39.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_627.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_29.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_163.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_771.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_539.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_719.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_686.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_885.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_658.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_280.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_421.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_351.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1082.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_516.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_520.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1016.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_536.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_352.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1129.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_519.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1114.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1219.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_207.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_286.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_45.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_90.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_754.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training/pituitary/Tr-pi_1355.jpg
# ...
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_362.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_273.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_337.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_195.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_198.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_241.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_18.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_43.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_119.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_8.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_210.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_52.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_374.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_315.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_39.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_129.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_373.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_398.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_170.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_399.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_161.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_318.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_221.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_211.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_245.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_240.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_155.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_20.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_356.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_290.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_37.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_357.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_293.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_377.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_174.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_299.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_358.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_351.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_82.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_1.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_91.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_59.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_252.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_341.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_115.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_269.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_234.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_127.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_248.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_390.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_132.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_302.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_172.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_109.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_13.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_311.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_208.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_84.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_80.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_180.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_30.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_231.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_314.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_344.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_263.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_200.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_335.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_308.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_153.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_386.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_75.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_316.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_66.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_232.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_323.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_336.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_281.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_151.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_14.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_78.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_158.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_144.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_279.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_58.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_76.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_94.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_243.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_291.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_121.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_350.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_193.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_397.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_207.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_251.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_262.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_303.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_7.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_370.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_324.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_258.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_27.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_44.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_33.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_194.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_395.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_34.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_274.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_343.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_70.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_360.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_332.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_201.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_26.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_283.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_106.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_45.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_209.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_142.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_294.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_143.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_220.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_304.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_203.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_46.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_130.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_239.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_120.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_117.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_326.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_123.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_137.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_159.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_261.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_228.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_352.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_384.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_372.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_184.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_191.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_4.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_35.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_168.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_246.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_244.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_145.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_227.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_169.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_364.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_379.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_105.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_48.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_31.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_204.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_289.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_275.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_42.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_367.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_254.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_217.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_259.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_348.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_319.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_368.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_54.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_334.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_339.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_98.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_387.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_349.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_24.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_260.jpg
# /kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing/glioma/Te-gl_47.jpg

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
import gc
import os

# CLEANUP

gc.collect()
tf.keras.backend.clear_session()

# CONFIG

TRAIN_PATH = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Training'
TEST_PATH  = '/kaggle/input/datasets/masoudnickparvar/brain-tumor-mri-dataset/Testing'
IMG_SIZE   = (224, 224)
BATCH_SIZE = 32
AUTOTUNE   = tf.data.AUTOTUNE
all_images = []
all_labels = []
class_names = sorted(os.listdir(TRAIN_PATH))
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

for label_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(TRAIN_PATH, class_name)
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            all_images.append(os.path.join(class_dir, fname))
            all_labels.append(label_idx)


# TRAIN / VALIDATION SPLIT

train_paths, val_paths, train_labels, val_labels = train_test_split(
    all_images, all_labels,
    test_size=0.15,
    stratify=all_labels,
    random_state=42
)
print(f"Train: {len(train_paths)}")
print(f"Validation: {len(val_paths)}")

val_dist = Counter(val_labels)
print("Validation Distribution:")
print({class_names[k]: v for k, v in sorted(val_dist.items())})

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)

# Array form used later to build per-sample weights for the one-hot dataset
class_weights_arr = np.array(
    [class_weights[i] for i in range(NUM_CLASSES)], dtype=np.float32
)


# IMAGE LOADING

def load_image(path, label):
    img = tf.io.read_file(path)
    img = tf.image.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32) / 255.0
    return img, label

# AUGMENTATION

_aug_rotate = tf.keras.layers.RandomRotation(0.10, fill_mode='reflect')
_aug_zoom   = tf.keras.layers.RandomZoom(0.10,   fill_mode='reflect')

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_flip_up_down(img)
    img = tf.image.random_brightness(img, 0.15)
    img = tf.image.random_contrast(img, 0.85, 1.15)
    img = tf.image.random_saturation(img, 0.85, 1.15)

    img = tf.expand_dims(img, 0)
    img = _aug_rotate(img, training=True)
    img = _aug_zoom(img,   training=True)
    img = tf.squeeze(img, 0)

    img = tf.clip_by_value(img, 0.0, 1.0)
    return img, label

# TRAIN DATASET

train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_ds = train_ds.shuffle(len(train_paths), seed=42, reshuffle_each_iteration=True)
train_ds = train_ds.map(load_image, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.cache()
train_ds = train_ds.map(augment, num_parallel_calls=AUTOTUNE)
train_ds = train_ds.batch(BATCH_SIZE)
train_ds = train_ds.prefetch(AUTOTUNE)


# VALIDATION DATASET

val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
val_ds = val_ds.map(load_image, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.cache()
val_ds = val_ds.batch(BATCH_SIZE)
val_ds = val_ds.prefetch(AUTOTUNE)

# TEST DATASET

test_images, test_labels = [], []
for label_idx, class_name in enumerate(class_names):
    class_dir = os.path.join(TEST_PATH, class_name)
    for fname in os.listdir(class_dir):
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            test_images.append(os.path.join(class_dir, fname))
            test_labels.append(label_idx)

test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
test_ds = test_ds.map(load_image, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.batch(BATCH_SIZE)
test_ds = test_ds.prefetch(AUTOTUNE)

# MODEL


def residual_block(x, filters, stride=1):
    """
    Pre-activation residual block (BN -> ReLU -> Conv).
    Shortcut uses 1x1 conv when dims change.
    """
    shortcut = x

    # Main path
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(
        filters, 3, strides=stride, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(
        filters, 3, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(x)

    if stride != 1 or shortcut.shape[-1] != filters:
        shortcut = layers.Conv2D(
            filters, 1, strides=stride, padding='same',
            use_bias=False, kernel_regularizer=l2(1e-4)
        )(shortcut)

    x = layers.Add()([x, shortcut])
    return x


def build_model():
    inputs = layers.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))

    # Stem
    x = layers.Conv2D(
        32, 7, strides=2, padding='same',
        use_bias=False, kernel_regularizer=l2(1e-4)
    )(inputs)                                          # 112x112x32
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D(3, strides=2, padding='same')(x)  # 56x56x32

    # Stage 1: 56x56
    x = residual_block(x, 64)
    x = residual_block(x, 64)

    # Stage 2: 28x28
    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128)

    # Stage 3: 14x14
    x = residual_block(x, 256, stride=2)
    x = residual_block(x, 256)

    # Stage 4: 7x7
    x = residual_block(x, 512, stride=2)
    x = residual_block(x, 512)

    # Head
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.40)(x)
    x = layers.Dense(
        256, activation='relu',
        kernel_regularizer=l2(1e-4)
    )(x)
    x = layers.Dropout(0.30)(x)
    outputs = layers.Dense(NUM_CLASSES, activation='softmax')(x)

    return models.Model(inputs, outputs)


# BUILD MODEL

model = build_model()

# ONE-HOT LABELS + PER-SAMPLE WEIGHTS
#
# We need one-hot labels for CategoricalCrossentropy + label_smoothing.
# Keras' `class_weight` argument to `fit()` does not reliably map onto
# one-hot targets coming from a tf.data.Dataset, so instead we bake the
# per-class weight into an explicit sample_weight for each batch.

def to_one_hot_with_sample_weight(img, label):
    label_oh = tf.one_hot(label, NUM_CLASSES)
    sample_weight = tf.gather(class_weights_arr, label)
    return img, label_oh, sample_weight

def to_one_hot(img, label):
    return img, tf.one_hot(label, NUM_CLASSES)

train_ds_oh = train_ds.map(to_one_hot_with_sample_weight, num_parallel_calls=AUTOTUNE)
val_ds_oh   = val_ds.map(to_one_hot, num_parallel_calls=AUTOTUNE)
test_ds_oh  = test_ds.map(to_one_hot, num_parallel_calls=AUTOTUNE)

model.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=3e-4,
        weight_decay=1e-4
    ),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

model.summary()

# CALLBACKS

callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        '/kaggle/working/best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# TRAIN
# NOTE: class_weight is no longer passed here since sample weights are
# already included as the 3rd element of each train_ds_oh batch.

history = model.fit(
    train_ds_oh,
    validation_data=val_ds_oh,
    epochs=60,
    callbacks=callbacks
)

# EVALUATE

loss, acc = model.evaluate(test_ds_oh)
print(f"\nTest Accuracy : {round(acc, 4)}")
print(f"Test Loss     : {round(loss, 4)}")

# TRAINING CURVES

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(history.history['accuracy'],     label='Train Acc')
axes[0].plot(history.history['val_accuracy'], label='Val Acc')
axes[0].set_title('Accuracy'); axes[0].legend(); axes[0].grid(True)

axes[1].plot(history.history['loss'],     label='Train Loss')
axes[1].plot(history.history['val_loss'], label='Val Loss')
axes[1].set_title('Loss'); axes[1].legend(); axes[1].grid(True)

plt.tight_layout()
plt.savefig('/kaggle/working/training_curves.png', dpi=150)
plt.show()

# SAVE

model.save('/kaggle/working/final_model.keras')
print("Model saved successfully.")
# Out:
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
# Train: 4760
# Validation: 840
# Validation Distribution:
# {'glioma': 210, 'meningioma': 210, 'notumor': 210, 'pituitary': 210}
# Class Weights: {0: np.float64(1.0), 1: np.float64(1.0), 2: np.float64(1.0), 3: np.float64(1.0)}
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1784102671.484115      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1784102671.486882      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 112, 112,  │      4,704 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 112, 112,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 56, 56,    │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        128 │ max_pooling2d[0]… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 56, 56,    │     18,432 │ activation_1[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 56, 56,    │      2,048 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 56, 56,    │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ add[0][0]         │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_3[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 56, 56,    │     36,864 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 56, 56,    │          0 │ conv2d_5[0][0],   │
# │                     │ 64)               │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 56, 56,    │        256 │ add_1[0][0]       │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 56, 56,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 28, 28,    │     73,728 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 28, 28,    │    147,456 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 28, 28,    │      8,192 │ add_1[0][0]       │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 28, 28,    │          0 │ conv2d_7[0][0],   │
# │                     │ 128)              │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 28, 28,    │    147,456 │ activation_7[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 28, 28,    │    147,456 │ activation_8[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 28, 28,    │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        512 │ add_3[0][0]       │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 14, 14,    │    294,912 │ activation_9[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_10[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 14, 14,    │     32,768 │ add_3[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 14, 14,    │          0 │ conv2d_12[0][0],  │
# │                     │ 256)              │            │ conv2d_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ add_4[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_11[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 14, 14,    │    589,824 │ activation_12[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 14, 14,    │          0 │ conv2d_15[0][0],  │
# │                     │ 256)              │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │      1,024 │ add_5[0][0]       │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 7, 7, 512) │  1,179,648 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 7, 7, 512) │    131,072 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 7, 7, 512) │          0 │ conv2d_17[0][0],  │
# │                     │                   │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ add_6[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 7, 7, 512) │  2,359,296 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 7, 7, 512) │          0 │ conv2d_20[0][0],  │
# │                     │                   │            │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 512) │      2,048 │ add_7[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 512) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_17[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 512)       │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    131,328 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 4)         │      1,028 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 11,293,796 (43.08 MB)
#  Trainable params: 11,285,988 (43.05 MB)
#  Non-trainable params: 7,808 (30.50 KB)
# Epoch 1/60
#   1/149 ━━━━━━━━━━━━━━━━━━━━ 1:03:54 26s/step - accuracy: 0.1250 - loss: 1.9971
# I0000 00:00:1784102700.260701     131 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.5231 - loss: 1.6294
# Epoch 1: val_accuracy improved from None to 0.25000, saving model to /kaggle/working/best_model.keras
#
# Epoch 1: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 80s 364ms/step - accuracy: 0.5952 - loss: 1.5273 - val_accuracy: 0.2500 - val_loss: 2.8269 - learning_rate: 3.0000e-04
# Epoch 2/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6899 - loss: 1.3600
# Epoch 2: val_accuracy improved from 0.25000 to 0.31310, saving model to /kaggle/working/best_model.keras
#
# Epoch 2: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.7216 - loss: 1.3097 - val_accuracy: 0.3131 - val_loss: 2.8352 - learning_rate: 3.0000e-04
# Epoch 3/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7727 - loss: 1.2103
# Epoch 3: val_accuracy improved from 0.31310 to 0.71310, saving model to /kaggle/working/best_model.keras
#
# Epoch 3: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 204ms/step - accuracy: 0.7834 - loss: 1.1913 - val_accuracy: 0.7131 - val_loss: 1.3097 - learning_rate: 3.0000e-04
# Epoch 4/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.7995 - loss: 1.1546
# Epoch 4: val_accuracy improved from 0.71310 to 0.85357, saving model to /kaggle/working/best_model.keras
#
# Epoch 4: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 208ms/step - accuracy: 0.8128 - loss: 1.1219 - val_accuracy: 0.8536 - val_loss: 1.0285 - learning_rate: 3.0000e-04
# Epoch 5/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8207 - loss: 1.0752
# Epoch 5: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8334 - loss: 1.0566 - val_accuracy: 0.2548 - val_loss: 3.8265 - learning_rate: 3.0000e-04
# Epoch 6/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8531 - loss: 1.0070
# Epoch 6: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8567 - loss: 0.9969 - val_accuracy: 0.6583 - val_loss: 1.3078 - learning_rate: 3.0000e-04
# Epoch 7/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8642 - loss: 0.9707
# Epoch 7: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8704 - loss: 0.9509 - val_accuracy: 0.7000 - val_loss: 1.2243 - learning_rate: 3.0000e-04
# Epoch 8/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8710 - loss: 0.9305
# Epoch 8: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8777 - loss: 0.9116 - val_accuracy: 0.8202 - val_loss: 1.0005 - learning_rate: 3.0000e-04
# Epoch 9/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8820 - loss: 0.8976
# Epoch 9: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.8922 - loss: 0.8750 - val_accuracy: 0.7119 - val_loss: 1.1433 - learning_rate: 3.0000e-04
# Epoch 10/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8917 - loss: 0.8557
# Epoch 10: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.8989 - loss: 0.8469 - val_accuracy: 0.6155 - val_loss: 1.3330 - learning_rate: 3.0000e-04
# Epoch 11/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8966 - loss: 0.8349
# Epoch 11: val_accuracy did not improve from 0.85357
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 202ms/step - accuracy: 0.9021 - loss: 0.8221 - val_accuracy: 0.8250 - val_loss: 0.9213 - learning_rate: 3.0000e-04
# Epoch 12/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9120 - loss: 0.8067
# Epoch 12: val_accuracy improved from 0.85357 to 0.87143, saving model to /kaggle/working/best_model.keras
#
# Epoch 12: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9101 - loss: 0.8001 - val_accuracy: 0.8714 - val_loss: 0.8326 - learning_rate: 3.0000e-04
# Epoch 13/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9051 - loss: 0.7963
# Epoch 13: val_accuracy did not improve from 0.87143
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 203ms/step - accuracy: 0.9103 - loss: 0.7856 - val_accuracy: 0.4762 - val_loss: 1.8545 - learning_rate: 3.0000e-04
# Epoch 14/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9061 - loss: 0.7826
# Epoch 14: val_accuracy improved from 0.87143 to 0.90119, saving model to /kaggle/working/best_model.keras
#
# Epoch 14: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9103 - loss: 0.7712 - val_accuracy: 0.9012 - val_loss: 0.7864 - learning_rate: 3.0000e-04
# Epoch 15/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9102 - loss: 0.7678
# Epoch 15: val_accuracy improved from 0.90119 to 0.91190, saving model to /kaggle/working/best_model.keras
#
# Epoch 15: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.9181 - loss: 0.7503 - val_accuracy: 0.9119 - val_loss: 0.7390 - learning_rate: 3.0000e-04
# Epoch 16/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9115 - loss: 0.7517
# Epoch 16: val_accuracy did not improve from 0.91190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9185 - loss: 0.7407 - val_accuracy: 0.8655 - val_loss: 0.8072 - learning_rate: 3.0000e-04
# Epoch 17/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9167 - loss: 0.7414
# Epoch 17: val_accuracy did not improve from 0.91190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 204ms/step - accuracy: 0.9225 - loss: 0.7258 - val_accuracy: 0.8393 - val_loss: 0.8246 - learning_rate: 3.0000e-04
# Epoch 18/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9237 - loss: 0.7222
# Epoch 18: val_accuracy improved from 0.91190 to 0.93095, saving model to /kaggle/working/best_model.keras
#
# Epoch 18: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.9250 - loss: 0.7137 - val_accuracy: 0.9310 - val_loss: 0.6934 - learning_rate: 3.0000e-04
# Epoch 19/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9187 - loss: 0.7197
# Epoch 19: val_accuracy did not improve from 0.93095
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9273 - loss: 0.7013 - val_accuracy: 0.8202 - val_loss: 0.8561 - learning_rate: 3.0000e-04
# Epoch 20/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9100 - loss: 0.7261
# Epoch 20: val_accuracy did not improve from 0.93095
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9176 - loss: 0.7147 - val_accuracy: 0.7083 - val_loss: 1.0965 - learning_rate: 3.0000e-04
# Epoch 21/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9241 - loss: 0.6931
# Epoch 21: val_accuracy did not improve from 0.93095
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9326 - loss: 0.6833 - val_accuracy: 0.9274 - val_loss: 0.6973 - learning_rate: 3.0000e-04
# Epoch 22/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9284 - loss: 0.6910
# Epoch 22: val_accuracy did not improve from 0.93095
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9313 - loss: 0.6821 - val_accuracy: 0.8214 - val_loss: 0.9282 - learning_rate: 3.0000e-04
# Epoch 23/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9272 - loss: 0.6857
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 23: val_accuracy did not improve from 0.93095
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9342 - loss: 0.6735 - val_accuracy: 0.8369 - val_loss: 0.8307 - learning_rate: 3.0000e-04
# Epoch 24/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9429 - loss: 0.6627
# Epoch 24: val_accuracy improved from 0.93095 to 0.96190, saving model to /kaggle/working/best_model.keras
#
# Epoch 24: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 205ms/step - accuracy: 0.9504 - loss: 0.6438 - val_accuracy: 0.9619 - val_loss: 0.6164 - learning_rate: 1.5000e-04
# Epoch 25/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9501 - loss: 0.6305
# Epoch 25: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 202ms/step - accuracy: 0.9548 - loss: 0.6254 - val_accuracy: 0.9500 - val_loss: 0.6248 - learning_rate: 1.5000e-04
# Epoch 26/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9524 - loss: 0.6290
# Epoch 26: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9586 - loss: 0.6194 - val_accuracy: 0.9464 - val_loss: 0.6366 - learning_rate: 1.5000e-04
# Epoch 27/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9507 - loss: 0.6195
# Epoch 27: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9542 - loss: 0.6172 - val_accuracy: 0.9179 - val_loss: 0.6777 - learning_rate: 1.5000e-04
# Epoch 28/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9538 - loss: 0.6216
# Epoch 28: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9590 - loss: 0.6112 - val_accuracy: 0.9536 - val_loss: 0.6047 - learning_rate: 1.5000e-04
# Epoch 29/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9592 - loss: 0.6071
# Epoch 29: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9630 - loss: 0.6004 - val_accuracy: 0.9179 - val_loss: 0.6695 - learning_rate: 1.5000e-04
# Epoch 30/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9552 - loss: 0.6127
# Epoch 30: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9582 - loss: 0.6034 - val_accuracy: 0.9595 - val_loss: 0.5969 - learning_rate: 1.5000e-04
# Epoch 31/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9621 - loss: 0.5990
# Epoch 31: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9647 - loss: 0.5933 - val_accuracy: 0.9464 - val_loss: 0.6161 - learning_rate: 1.5000e-04
# Epoch 32/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9598 - loss: 0.5954
# Epoch 32: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9595 - loss: 0.5957 - val_accuracy: 0.9464 - val_loss: 0.6093 - learning_rate: 1.5000e-04
# Epoch 33/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9560 - loss: 0.5994
# Epoch 33: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9613 - loss: 0.5916 - val_accuracy: 0.9536 - val_loss: 0.6101 - learning_rate: 1.5000e-04
# Epoch 34/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9603 - loss: 0.5933
# Epoch 34: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9630 - loss: 0.5843 - val_accuracy: 0.9143 - val_loss: 0.6755 - learning_rate: 1.5000e-04
# Epoch 35/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9627 - loss: 0.5890
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 35: val_accuracy did not improve from 0.96190
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9637 - loss: 0.5836 - val_accuracy: 0.9321 - val_loss: 0.6291 - learning_rate: 1.5000e-04
# Epoch 36/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9649 - loss: 0.5747
# Epoch 36: val_accuracy improved from 0.96190 to 0.97619, saving model to /kaggle/working/best_model.keras
#
# Epoch 36: finished saving model to /kaggle/working/best_model.keras
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - accuracy: 0.9725 - loss: 0.5641 - val_accuracy: 0.9762 - val_loss: 0.5575 - learning_rate: 7.5000e-05
# Epoch 37/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9755 - loss: 0.5572
# Epoch 37: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9798 - loss: 0.5507 - val_accuracy: 0.9440 - val_loss: 0.6158 - learning_rate: 7.5000e-05
# Epoch 38/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9726 - loss: 0.5536
# Epoch 38: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9775 - loss: 0.5487 - val_accuracy: 0.9738 - val_loss: 0.5557 - learning_rate: 7.5000e-05
# Epoch 39/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9785 - loss: 0.5480
# Epoch 39: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9769 - loss: 0.5489 - val_accuracy: 0.9679 - val_loss: 0.5728 - learning_rate: 7.5000e-05
# Epoch 40/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9775 - loss: 0.5497
# Epoch 40: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9809 - loss: 0.5441 - val_accuracy: 0.9667 - val_loss: 0.5656 - learning_rate: 7.5000e-05
# Epoch 41/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9782 - loss: 0.5471
# Epoch 41: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9775 - loss: 0.5454 - val_accuracy: 0.9393 - val_loss: 0.6096 - learning_rate: 7.5000e-05
# Epoch 42/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9800 - loss: 0.5392
# Epoch 42: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9817 - loss: 0.5369 - val_accuracy: 0.9679 - val_loss: 0.5609 - learning_rate: 7.5000e-05
# Epoch 43/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9846 - loss: 0.5349
# Epoch 43: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9847 - loss: 0.5346 - val_accuracy: 0.9714 - val_loss: 0.5509 - learning_rate: 7.5000e-05
# Epoch 44/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9832 - loss: 0.5332
# Epoch 44: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9834 - loss: 0.5318 - val_accuracy: 0.9464 - val_loss: 0.5941 - learning_rate: 7.5000e-05
# Epoch 45/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9771 - loss: 0.5370
# Epoch 45: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9796 - loss: 0.5359 - val_accuracy: 0.9679 - val_loss: 0.5536 - learning_rate: 7.5000e-05
# Epoch 46/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9804 - loss: 0.5355
# Epoch 46: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9821 - loss: 0.5312 - val_accuracy: 0.9690 - val_loss: 0.5438 - learning_rate: 7.5000e-05
# Epoch 47/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9858 - loss: 0.5236
# Epoch 47: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9838 - loss: 0.5270 - val_accuracy: 0.9762 - val_loss: 0.5491 - learning_rate: 7.5000e-05
# Epoch 48/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.9829 - loss: 0.5273
# Epoch 48: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 200ms/step - accuracy: 0.9828 - loss: 0.5265 - val_accuracy: 0.9690 - val_loss: 0.5517 - learning_rate: 7.5000e-05
# Epoch 49/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9814 - loss: 0.5299
# Epoch 49: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9836 - loss: 0.5263 - val_accuracy: 0.9500 - val_loss: 0.6001 - learning_rate: 7.5000e-05
# Epoch 50/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.9819 - loss: 0.5294
# Epoch 50: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 199ms/step - accuracy: 0.9830 - loss: 0.5255 - val_accuracy: 0.9702 - val_loss: 0.5464 - learning_rate: 7.5000e-05
# Epoch 51/60
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.9895 - loss: 0.5171
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 51: val_accuracy did not improve from 0.97619
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 30s 201ms/step - accuracy: 0.9866 - loss: 0.5203 - val_accuracy: 0.9655 - val_loss: 0.5703 - learning_rate: 7.5000e-05
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 36.
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9344 - loss: 0.6772
#
# Test Accuracy : 0.9344
# Test Loss     : 0.6772
# Model saved successfully.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

y_pred_probs = model.predict(test_ds_oh)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_ds_oh], axis=0)

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names,
            cmap='Blues')
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('/kaggle/working/confusion_matrix.png', dpi=150)
plt.show()

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.79      0.88       400
#   meningioma       0.89      0.97      0.93       400
#      notumor       0.91      0.99      0.95       400
#    pituitary       0.95      0.98      0.97       400
#
#     accuracy                           0.93      1600
#    macro avg       0.94      0.93      0.93      1600
# weighted avg       0.94      0.93      0.93      1600

# %%
# F1 SCORE, PRECISION, RECALL

from sklearn.metrics import classification_report

y_pred_probs = model.predict(test_ds_oh)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.concatenate([np.argmax(y.numpy(), axis=1) for _, y in test_ds_oh], axis=0)

print("\n========= Classification Report =========")
print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step
#
# ========= Classification Report =========
#               precision    recall  f1-score   support
#
#       glioma       0.99      0.79      0.88       400
#   meningioma       0.89      0.97      0.93       400
#      notumor       0.91      0.99      0.95       400
#    pituitary       0.95      0.98      0.97       400
#
#     accuracy                           0.93      1600
#    macro avg       0.94      0.93      0.93      1600
# weighted avg       0.94      0.93      0.93      1600
